# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
import pandas as pd
dataset = pd.read_csv('C:/Users/Am/Desktop/RNN/input/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# %%
import matplotlib.pyplot as plt
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
import numpy as np
X_train = []
y_train = []
for i in range(60,2769):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import LSTM
from tensorflow.keras.layers import Dense
from keras.layers import Dropout
regressor = Sequential()
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1))
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 16s 86ms/step - loss: 0.0202
# Epoch 2/50
# 85/85 [==============================] - 7s 84ms/step - loss: 0.0100
# Epoch 3/50
# 85/85 [==============================] - 7s 84ms/step - loss: 0.0085
# Epoch 4/50
# 85/85 [==============================] - 7s 88ms/step - loss: 0.0071
# Epoch 5/50
# 85/85 [==============================] - 8s 93ms/step - loss: 0.0064
# Epoch 6/50
# 85/85 [==============================] - 8s 89ms/step - loss: 0.0057
# Epoch 7/50
# 85/85 [==============================] - 7s 86ms/step - loss: 0.0051
# Epoch 8/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0051
# Epoch 9/50
# 85/85 [==============================] - 7s 86ms/step - loss: 0.0045
# Epoch 10/50
# 85/85 [==============================] - 7s 86ms/step - loss: 0.0042
# Epoch 11/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0039
# Epoch 12/50
# 85/85 [==============================] - 7s 86ms/step - loss: 0.0038
# Epoch 13/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0033
# Epoch 14/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0035
# Epoch 15/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0032
# Epoch 16/50
# 85/85 [==============================] - 7s 86ms/step - loss: 0.0031
# Epoch 17/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0030
# Epoch 18/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0030
# Epoch 19/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0029
# Epoch 20/50
# 85/85 [==============================] - 7s 84ms/step - loss: 0.0028
# Epoch 21/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0026
# Epoch 22/50
# 85/85 [==============================] - 7s 85ms/step - loss: 0.0025
# Epoch 23/50
# 85/85 [==============================] - 7s 88ms/step - loss: 0.0022
# Epoch 24/50
# 85/85 [==============================] - 8s 93ms/step - loss: 0.0026
# Epoch 25/50
# 85/85 [==============================] - 8s 95ms/step - loss: 0.0025
# Epoch 26/50
# 85/85 [==============================] - 8s 96ms/step - loss: 0.0023
# Epoch 27/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0022
# Epoch 28/50
# 85/85 [==============================] - 8s 99ms/step - loss: 0.0023
# Epoch 29/50
# 85/85 [==============================] - 8s 99ms/step - loss: 0.0022
# Epoch 30/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0022
# Epoch 31/50
# 85/85 [==============================] - 8s 99ms/step - loss: 0.0019
# Epoch 32/50
# 85/85 [==============================] - 8s 99ms/step - loss: 0.0021
# Epoch 33/50
# 85/85 [==============================] - 9s 101ms/step - loss: 0.0021
# Epoch 34/50
# 85/85 [==============================] - 8s 100ms/step - loss: 0.0019
# Epoch 35/50
# 85/85 [==============================] - 8s 99ms/step - loss: 0.0021
# Epoch 36/50
# 85/85 [==============================] - 8s 100ms/step - loss: 0.0019
# Epoch 37/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0018
# Epoch 38/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0017
# Epoch 39/50
# 85/85 [==============================] - 8s 99ms/step - loss: 0.0018
# Epoch 40/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0018
# Epoch 41/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0017
# Epoch 42/50
# 85/85 [==============================] - 8s 97ms/step - loss: 0.0017
# Epoch 43/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0017
# Epoch 44/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0016
# Epoch 45/50
# 85/85 [==============================] - 8s 97ms/step - loss: 0.0016
# Epoch 46/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0016
# Epoch 47/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0016
# Epoch 48/50
# 85/85 [==============================] - 8s 97ms/step - loss: 0.0016
# Epoch 49/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0015
# Epoch 50/50
# 85/85 [==============================] - 8s 98ms/step - loss: 0.0015

# %%
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
# Out:
# 8/8 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Am\Desktop\RNN\RNN.ipynb Cell 11 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
#       <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> GRU_predicted_stock_price = regressorGRU.predict(X_test)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
#
# File c:\Users\Am\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_data.py:543, in MinMaxScaler.inverse_transform(self, X)
#     529 """Undo the scaling of X according to feature_range.
#     530
#     531 Parameters
#    (...)
#     539     Transformed data.
#     540 """
#     541 check_is_fitted(self)
# --> 543 X = check_array(
#     544     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     545 )
#     547 X -= self.min_
#     548 X /= self.scale_
#
# File c:\Users\Am\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:953, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#     952 if not allow_nd and array.ndim >= 3:
# --> 953     raise ValueError(
#     954         "Found array with dim %d. %s expected <= 2."
#     955         % (array.ndim, estimator_name)
#     956     )
#     958 if force_all_finite:
#     959     _assert_all_finite(
#     960         array,
#     961         input_name=input_name,
#     962         estimator_name=estimator_name,
#     963         allow_nan=force_all_finite == "allow-nan",
#     964     )
#
# ValueError: Found array with dim 3. None expected <= 2.

# %%
plot_predictions(test_set,predicted_stock_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Am\Desktop\RNN\RNN.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> plot_predictions(test_set,predicted_stock_price)
#
# NameError: name 'predicted_stock_price' is not defined

# %%
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 3.0497788420000274.

# %%
from keras.models import Sequential
import tensorflow as tf
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=10000,
    decay_rate=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

regressorGRU = Sequential()
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=50, activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(Dense(units=1))
regressorGRU.compile(optimizer=SGD(learning_rate=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')

regressorGRU.fit(X_train,y_train,epochs=50,batch_size=150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Am\Desktop\RNN\RNN.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
#       <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> regressorGRU = Sequential()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
#      <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a> regressorGRU.add(Dropout(0.2))
#      <a href='vscode-notebook-cell:/c%3A/Users/Am/Desktop/RNN/RNN.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a> regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
#
# NameError: name 'GRU' is not defined
